# %%
from gera_figura_N2 import gera_figura_N2

# %%
gera_figura_N2()

# %%
from metodo_dicotomia_N2 import metodo_dicotomia

# %%
metodo_dicotomia(0, 8, 0, 1, 1e-4)
# Out:
# Número de iterações:  13
# 0.10015869140625

# %%
metodo_dicotomia(0, 8, 0, 1, 0.0001)
# Out:
# Número de iterações:  13
# 0.10015869140625
